# %% [markdown]
# ##Tasks to be performed:
# 1.Import the dataset as a DataFrame and drop the first column.
# 2.Save it as 'top50.csv'.
# 3.Find the average Energy and Length of first 10 songs.
# 4.Find the total length of songs, group by genre from top to bottom.
# 5.Print the artist name with the most number of tracks in one genre.
# 6.Print the data of the tracks created by the artist from the previous question.

# %%
import pandas as pd

# %%
##importing the dataset

# %%
df = pd.read_csv('top50spotify.csv')

# %%
##Getting to understand the dataset

# %%
df.shape
# Out:
# (50, 14)

# %%
df.size
# Out:
# 700

# %%
df.describe()
# Out:
#        SerialNo.  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count   50.00000         50.000000  50.000000      50.00000       50.000000
# mean    25.50000        120.060000  64.060000      71.38000       -5.660000
# std     14.57738         30.898392  14.231913      11.92988        2.056448
# min      1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%     13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%     25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%     37.75000        137.500000  74.750000      79.75000       -4.000000
# max     50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# std    11.118306  22.336024   39.143879       18.995553     11.161596
# ...

# %%
df.columns
# Out:
# Index(['SerialNo.', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    SerialNo.                       Track.Name    Artist.Name           Genre  \
# 0          1                         Señorita   Shawn Mendes    canadian pop
# 1          2                            China       Anuel AA  reggaeton flow
# 2          3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3          4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4          5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
##Dropping the first column

# %%
top50csv = df.drop(df.columns[0],axis =1)

# %%
top50csv
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
##Energy and length of first 10 songs

# %%
first_ten_song = top50csv.iloc[0:10,[4,9]]

# %%
first_ten_song
# Out:
#    Energy  Length.
# 0      55      191
# 1      81      302
# 2      80      186
# 3      65      198
# 4      65      175
# 5      68      220
# 6      64      131
# 7      68      202
# 8      62      157
# 9      43      194

# %%
Average_Energy = first_ten_song.iloc[:,0].mean()
Average_Length = first_ten_song.iloc[:,1].mean()
print("The Average Energy of the first 10 songs is", Average_Energy)
print("The Average Length of the first 10 songs is", Average_Lengh)
# Out:
# The Average Energy of the first 10 songs is 65.1
# The Average Length of the first 10 songs is 195.6

# %%
top50csv
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
##Total length of songs, group by genre from top to bottom

# %%
Length_of_song = top50csv.groupby(['Genre'])['Length.'].sum().sort_values(ascending=False)

# %%
Length_of_song
# Out:
# Genre
# dance pop           1621
# pop                 1368
# latin               1126
# edm                  656
# reggaeton flow       611
# canadian hip hop     579
# panamanian pop       514
# reggaeton            427
# brostep              396
# electropop           389
# canadian pop         382
# dfw rap              333
# country rap          272
# australian pop       210
# atl hip hop          200
# boy band             181
# escape room          173
# big room             164
# r&b en espanol       162
# pop house            153
# trap music           131
# Name: Length., dtype: int64

# %%
##Artist name per number of tracks in a genre

# %%
Artist_track_per_genre = top50csv.groupby(['Artist.Name','Genre']).size()

# %%
Artist_track_per_genre
# Out:
# Artist.Name       Genre
# Ali Gatie         canadian hip hop    1
# Anuel AA          reggaeton flow      1
# Ariana Grande     dance pop           2
# Bad Bunny         reggaeton           1
# Billie Eilish     electropop          2
# Chris Brown       dance pop           1
# DJ Snake          dance pop           1
# Daddy Yankee      latin               1
# Drake             canadian hip hop    1
# Ed Sheeran        pop                 4
# J Balvin          latin               2
# Jhay Cortez       reggaeton flow      1
# Jonas Brothers    boy band            1
# Katy Perry        dance pop           1
# Khalid            pop                 1
# Kygo              edm                 1
# Lady Gaga         dance pop           1
# Lauv              dance pop           1
# Lewis Capaldi     pop                 1
# Lil Nas X         country rap         2
# Lil Tecca         trap music          1
# Lizzo             escape room         1
# Lunay             latin               1
# ...

# %%
max_tracks = Artist_track_per_genre.max()
max_artists = Artist_track_per_genre[Artist_track_per_genre == max_tracks]
print("Artist(s) with the maximum number of tracks:")
print(max_artists)
# Out:
# Artist(s) with the maximum number of tracks:
# Artist.Name  Genre
# Ed Sheeran   pop      4
# dtype: int64

# %%
##Data of the tracks created by Ed Sheeren

# %%
ed_sheeran_tracks = top50csv[top50csv["Artist.Name"] == "Ed Sheeran"]

# %%
ed_sheeran_tracks
# Out:
#                                        Track.Name Artist.Name Genre  \
# 3                 Beautiful People (feat. Khalid)  Ed Sheeran   pop
# 5               I Don't Care (with Justin Bieber)  Ed Sheeran   pop
# 37                 Antisocial (with Travis Scott)  Ed Sheeran   pop
# 49  Cross Me (feat. Chance the Rapper & PnB Rock)  Ed Sheeran   pop
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 3                 93      65            64              -8         8
# 5                102      68            80              -5         9
# 37               152      82            72              -5        36
# 49                95      79            75              -6         7
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 3         55      198              12            19          86
# 5         84      220               9             4          84
# 37        91      162              13             5          87
# ...
